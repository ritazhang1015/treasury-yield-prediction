# %% [markdown]
# # Treasury Yield Data Pipeline
#
# This notebook builds a monthly panel dataset (Jan 2015 – Dec 2024) of US
# macroeconomic indicators used to model US 10-Year Treasury yields.
#
# **Data sources:**
# - US 10Y, Federal Funds Rate, CPI, Unemployment Rate: FRED (CSV exports)
# - S&P 500, Gold, USD Index: Yahoo Finance via yfinance
# - China 10Y: separate CSV export
#
# **Output:** `Merged_Data.csv` with 120 monthly observations across 9 variables,
# used as input to econometric analysis in R (see `analysis.Rmd`).

# %% [markdown]
# # Import Data and Basic Timeframe Alignment

# %% [markdown]
# ## Market Index (S&P 500)

# %%
import yfinance as yf
import pandas as pd

# %%
sp500 = yf.download("^GSPC", start="2015-01-01", end="2024-12-31", interval="1d")
sp500.index = pd.to_datetime(sp500.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(sp500.columns)
# Out:
# MultiIndex([( 'Close', '^GSPC'),
#             (  'High', '^GSPC'),
#             (   'Low', '^GSPC'),
#             (  'Open', '^GSPC'),
#             ('Volume', '^GSPC')],
#            names=['Price', 'Ticker'])

# %%
sp500_eom = sp500.resample('M').last() #Select only the last business day of each month
sp500_eom= sp500_eom[['Close']].rename(columns={'Close': 'SP_500'})
print(sp500_eom.head)
# Out:
# <bound method NDFrame.head of Price            SP_500
# Ticker            ^GSPC
# Date
# 2015-01-31  1994.989990
# 2015-02-28  2104.500000
# 2015-03-31  2067.889893
# 2015-04-30  2085.510010
# 2015-05-31  2107.389893
# ...                 ...
# 2024-08-31  5648.399902
# 2024-09-30  5762.479980
# 2024-10-31  5705.450195
# 2024-11-30  6032.379883
# 2024-12-31  5906.939941
#
# [120 rows x 1 columns]>
# <ipython-input-60-b6cfd2cc8f7f>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sp500_eom = sp500.resample('M').last() #Select only the last business day of each month

# %%
sp500_eom.to_csv("sp500_monthly.csv")

# %% [markdown]
# ## Precious Metal Price Index (Gold Price)

# %%
gold = yf.download("GC=F", start="2015-01-01", end="2024-12-31", interval="1d")
gold.index = pd.to_datetime(gold.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold_eom = gold.resample('M').last() #Select only the last business day of each month
gold_eom = gold_eom[['Close']].rename(columns={'Close': 'Gold_Price'})
print(gold_eom.head)
# Out:
# <bound method NDFrame.head of Price        Gold_Price
# Ticker             GC=F
# Date
# 2015-01-31  1278.500000
# 2015-02-28  1212.599976
# 2015-03-31  1183.099976
# 2015-04-30  1182.400024
# 2015-05-31  1189.400024
# ...                 ...
# 2024-08-31  2493.800049
# 2024-09-30  2636.100098
# 2024-10-31  2738.300049
# 2024-11-30  2657.000000
# 2024-12-31  2606.100098
#
# [120 rows x 1 columns]>
# <ipython-input-63-f61473cd3508>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   gold_eom = gold.resample('M').last() #Select only the last business day of each month

# %%
gold_eom.to_csv("gold_monthly.csv")
print(gold_eom.head)
# Out:
# <bound method NDFrame.head of Price        Gold_Price
# Ticker             GC=F
# Date
# 2015-01-31  1278.500000
# 2015-02-28  1212.599976
# 2015-03-31  1183.099976
# 2015-04-30  1182.400024
# 2015-05-31  1189.400024
# ...                 ...
# 2024-08-31  2493.800049
# 2024-09-30  2636.100098
# 2024-10-31  2738.300049
# 2024-11-30  2657.000000
# 2024-12-31  2606.100098
#
# [120 rows x 1 columns]>

# %% [markdown]
# ## US Currency Index (USD Value)

# %%
usd = yf.download("DX-Y.NYB", start="2015-01-01", end="2024-12-31", interval="1d")
usd.index = pd.to_datetime(usd.index)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
usd_eom = usd.resample('M').last() #Select only the last business day of each month
usd_eom = usd_eom[['Close']].rename(columns={'Close': 'USD_Index'}) #Select only the last business day of each month
# Out:
# <ipython-input-66-e6f7734b2666>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   usd_eom = usd.resample('M').last() #Select only the last business day of each month

# %%
usd_eom.to_csv("usd_monthly.csv")
print(usd_eom.head)
# Out:
# <bound method NDFrame.head of Price        USD_Index
# Ticker        DX-Y.NYB
# Date
# 2015-01-31   94.800003
# 2015-02-28   95.250000
# 2015-03-31   98.360001
# 2015-04-30   94.599998
# 2015-05-31   96.910004
# ...                ...
# 2024-08-31  101.699997
# 2024-09-30  100.779999
# 2024-10-31  103.980003
# 2024-11-30  105.739998
# 2024-12-31  108.129997
#
# [120 rows x 1 columns]>

# %% [markdown]
# ## Interest Rate (Federal Funds Rate)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
file_path = "/content/drive/My Drive/Colab_Data/FEDFUNDS.csv"
# Out:
# Mounted at /content/drive

# %%
ffr = pd.read_csv(file_path, parse_dates=["observation_date"])
ffr.set_index("observation_date", inplace=True)

# %%
ffr.index = ffr.index - pd.DateOffset(days=1)

# %%
ffr.rename(columns={"FEDFUNDS": "Fed_Funds_Rate"}, inplace=True)

# %%
print(ffr.head)
# Out:
# <bound method NDFrame.head of                   Fed_Funds_Rate
# observation_date
# 2015-01-31                  0.11
# 2015-02-28                  0.11
# 2015-03-31                  0.12
# 2015-04-30                  0.12
# 2015-05-31                  0.13
# ...                          ...
# 2024-08-31                  5.13
# 2024-09-30                  4.83
# 2024-10-31                  4.64
# 2024-11-30                  4.48
# 2024-12-31                  4.33
#
# [120 rows x 1 columns]>

# %%
output_path = "/content/drive/My Drive/Colab_Data/FEDFUNDS_Adjusted.csv"
ffr.to_csv(output_path)
ffr.to_csv("fed_funds_rate.csv")

# %% [markdown]
# ## Inflation Rate (based on Consumer Price Index)

# %%
file_path = "/content/drive/My Drive/Colab_Data/CPIAUCSL.csv"

# %%
cpi = pd.read_csv(file_path, parse_dates=["observation_date"])
cpi.set_index("observation_date", inplace=True)

# %%
cpi.index = cpi.index - pd.DateOffset(days=1)

# %%
cpi.rename(columns={"CPIAUCSL": "CPI"}, inplace=True)

# %%
print(cpi.head)
# Out:
# <bound method NDFrame.head of                       CPI
# observation_date
# 2015-01-31        235.342
# 2015-02-28        235.976
# 2015-03-31        236.222
# 2015-04-30        237.001
# 2015-05-31        237.657
# ...                   ...
# 2024-08-31        314.851
# 2024-09-30        315.564
# 2024-10-31        316.449
# 2024-11-30        317.603
# 2024-12-31        319.086
#
# [120 rows x 1 columns]>

# %%
cpi["Inflation_Rate"] = cpi["CPI"].pct_change() * 100

# %%
# pct_change() produces NaN for the first observation (Jan 2015) since
# we don't have December 2014 CPI loaded. Manually fill with the value
# computed from FRED CPI data outside this notebook.
# Note: this affects 1 observation; the final model also drops early
# rows due to 2-month inflation lag, minimizing impact.
cpi.iloc[0, cpi.columns.get_loc("Inflation_Rate")] = 0.2535

# %%
print(cpi.head)
# Out:
# <bound method NDFrame.head of                       CPI  Inflation_Rate
# observation_date
# 2015-01-31        235.342        0.253500
# 2015-02-28        235.976        0.269395
# 2015-03-31        236.222        0.104248
# 2015-04-30        237.001        0.329775
# 2015-05-31        237.657        0.276792
# ...                   ...             ...
# 2024-08-31        314.851        0.229204
# 2024-09-30        315.564        0.226456
# 2024-10-31        316.449        0.280450
# 2024-11-30        317.603        0.364672
# 2024-12-31        319.086        0.466935
#
# [120 rows x 2 columns]>

# %%
output_path = "/content/drive/My Drive/Colab_Data/CPIAUCSL_Adjusted.csv"
cpi.to_csv(output_path)
cpi.to_csv("cpi.csv")

# %% [markdown]
# ## Foreign Bond Yields (China 10Y)

# %%
file_path = "/content/drive/My Drive/Colab_Data/china10y.csv"

# %%
cn10y = pd.read_csv(file_path, parse_dates=["Date"])
cn10y.set_index("Date", inplace=True)

# %%
cn10y_eom = cn10y.resample('M').last() #Select only the last business day of each month
cn10y_eom = cn10y_eom[['Close']].rename(columns={'Close': 'China_10Y'})
print(cn10y_eom.head)
# Out:
# <bound method NDFrame.head of             China_10Y
# Date
# 2015-01-31      2.010
# 2015-02-28      2.123
# 2015-03-31      2.152
# 2015-04-30      2.112
# 2015-05-31      2.164
# ...               ...
# 2024-08-31      3.430
# 2024-09-30      3.670
# 2024-10-31      3.550
# 2024-11-30      3.500
# 2024-12-31      3.680
#
# [120 rows x 1 columns]>
# <ipython-input-105-ea5498864619>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   cn10y_eom = cn10y.resample('M').last() #Select only the last business day of each month

# %%
cn10y_eom.to_csv("cn10y_monthly.csv")
print(cn10y_eom.head)
# Out:
# <bound method NDFrame.head of             China_10Y
# Date
# 2015-01-31      2.010
# 2015-02-28      2.123
# 2015-03-31      2.152
# 2015-04-30      2.112
# 2015-05-31      2.164
# ...               ...
# 2024-08-31      3.430
# 2024-09-30      3.670
# 2024-10-31      3.550
# 2024-11-30      3.500
# 2024-12-31      3.680
#
# [120 rows x 1 columns]>

# %% [markdown]
# ## Unemployment Rate

# %%
file_path = "/content/drive/My Drive/Colab_Data/UNRATE.csv"

# %%
unrate = pd.read_csv(file_path, parse_dates=["observation_date"])
unrate.set_index("observation_date", inplace=True)

# %%
unrate.index = unrate.index - pd.DateOffset(days=1)

# %%
print(unrate.head)
# Out:
# <bound method NDFrame.head of                   UNRATE
# observation_date
# 2015-01-31           5.5
# 2015-02-28           5.4
# 2015-03-31           5.4
# 2015-04-30           5.6
# 2015-05-31           5.3
# ...                  ...
# 2024-08-31           4.1
# 2024-09-30           4.1
# 2024-10-31           4.2
# 2024-11-30           4.1
# 2024-12-31           4.0
#
# [120 rows x 1 columns]>

# %%
output_path = "/content/drive/My Drive/Colab_Data/UNRATE_Adjusted.csv"
unrate.to_csv(output_path)
unrate.to_csv("unrate.csv")

# %% [markdown]
# ## Response variable: US10Y

# %%
file_path = "/content/drive/My Drive/Colab_Data/DGS10.csv"

# %%
us10 = pd.read_csv(file_path, parse_dates=["observation_date"])
us10.set_index("observation_date", inplace=True)

# %%
us10_eom = us10.resample('M').last() #Select only the last business day of each month
us10_eom= us10_eom[['DGS10']].rename(columns={'DGS10': 'US_10Y'})
print(us10_eom.head)
# Out:
# <bound method NDFrame.head of                   US_10Y
# observation_date
# 2015-01-31          1.68
# 2015-02-28          2.00
# 2015-03-31          1.94
# 2015-04-30          2.05
# 2015-05-31          2.12
# ...                  ...
# 2024-09-30          3.81
# 2024-10-31          4.28
# 2024-11-30          4.18
# 2024-12-31          4.58
# 2025-01-31           NaN
#
# [121 rows x 1 columns]>
# <ipython-input-132-98d904924317>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   us10_eom = us10.resample('M').last() #Select only the last business day of each month

# %%
us10_eom = us10_eom.drop(us10_eom.index[-1])
print(us10_eom.head)
# Out:
# <bound method NDFrame.head of                   US_10Y
# observation_date
# 2015-01-31          1.68
# 2015-02-28          2.00
# 2015-03-31          1.94
# 2015-04-30          2.05
# 2015-05-31          2.12
# ...                  ...
# 2024-08-31          3.91
# 2024-09-30          3.81
# 2024-10-31          4.28
# 2024-11-30          4.18
# 2024-12-31          4.58
#
# [120 rows x 1 columns]>

# %%
output_path = "/content/drive/My Drive/Colab_Data/DGS10_Adjusted.csv"
us10_eom.to_csv(output_path)
us10_eom.to_csv("us10_monthly.csv")

# %% [markdown]
# ## Additional Action: Save CSVs to Google Drive

# %%
import shutil

# %%
files = ["cn10y_monthly.csv", "gold_monthly.csv", "sp500_monthly.csv", "usd_monthly.csv"]
# I accidentally deleted the local files, so this step is to make a copy from GDrive back to here

# %%
source_folder = "/content/drive/My Drive/Colab_Data/"

# %%
for file in files:
    shutil.copy(source_folder + file, file)

# %% [markdown]
# # Clean a Few Datasets

# %% [markdown]
# # Merge Datasets

# %%
cn10y = pd.read_csv("cn10y_monthly.csv", parse_dates=["Date"], index_col="Date")
cpi = pd.read_csv("cpi.csv", parse_dates=["observation_date"], index_col="observation_date")
fed_funds_rate = pd.read_csv("fed_funds_rate.csv", parse_dates=["observation_date"], index_col="observation_date")
gold = pd.read_csv("gold_monthly.csv", skiprows=2, parse_dates=["Date"], index_col="Date")
sp500 = pd.read_csv("sp500_monthly.csv", skiprows=2, parse_dates=["Date"], index_col="Date")
unrate = pd.read_csv("unrate.csv", parse_dates=["observation_date"], index_col="observation_date")
us10y = pd.read_csv("us10_monthly.csv", parse_dates=["observation_date"], index_col="observation_date")  # Response variable
usd = pd.read_csv("usd_monthly.csv",skiprows=2, parse_dates=["Date"], index_col="Date")
# Out:
# <ipython-input-137-515d533b5e2b>:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   gold = pd.read_csv("gold_monthly.csv", parse_dates=["Price"], index_col="Price")
# <ipython-input-137-515d533b5e2b>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500 = pd.read_csv("sp500_monthly.csv", parse_dates=["Price"], index_col="Price")
# <ipython-input-137-515d533b5e2b>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   usd = pd.read_csv("usd_monthly.csv", parse_dates=["Price"], index_col="Price")

# %%
merged_data = cn10y.merge(cpi, on="Date", how="inner")\
                   .merge(fed_funds_rate, on="Date", how="inner")\
                   .merge(gold, on="Date", how="inner")\
                   .merge(sp500, on="Date", how="inner")\
                   .merge(unrate, on="Date", how="inner")\
                   .merge(us10y, on="Date", how="inner")\
                   .merge(usd, on="Date", how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-fe7571243a57> in <cell line: 0>()
# ----> 1 merged_data = cn10y.merge(cpi, on="Date", how="inner")\
#       2                    .merge(fed_funds_rate, on="Date", how="inner")\
#       3                    .merge(gold, on="Date", how="inner")\
#       4                    .merge(sp500, on="Date", how="inner")\
#       5                    .merge(unrate, on="Date", how="inner")\
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'Date'
